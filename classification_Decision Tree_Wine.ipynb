# %% [markdown]
# [課程Github網址](https://github.com/Elwing-Chou/MLDemo1211)

# %%
# import pckages
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import pandas as pd

# %%
# load data
wine = load_wine()

# randomly divide the data into training data(90%) and testing data(10%)
x_train, x_test, y_train, y_test = train_test_split(wine["data"], wine["target"], test_size = 0.1, random_state = 123)

# %%
# Build Decision Tree Model
clf = DecisionTreeClassifier(max_depth = 2) # The teacher set the parameter by seeing the graphics
clf.fit(x_train, y_train)

# Test
pre = clf.predict(x_test)
accuracy_score(pre, y_test)
# Out:
# 0.9444444444444444

# %%
# draw pictures
import graphviz
from sklearn.tree import export_graphviz

# %%
g = export_graphviz(clf,
                                       feature_names= wine["feature_names"],
                                       class_names = wine["target_names"],
                                       filled = True)
graphviz.Source(g)
